# %%
from matplotlib import pyplot as plt
import numpy as np
import math as math
import pandas as pd

# %%
dataset = []
data_range = []
amount = 100


for values in range(amount):
    data_range.append(values)
    dataset.append(np.random.randint(1, amount))

plot_dataset(data_range, dataset)

# %%
def plot_dataset(x, y):
    plt.scatter(x, y)
    plt.show()
